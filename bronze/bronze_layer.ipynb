# %%
import pandas as pd
import os
from datetime import datetime as dt

# %%
df = pd.read_csv('c:/Users/rafae/git/pipeline/twitter_sentment.csv', encoding='latin-1')

print(f"Dados carregados: {df.shape[0]} linhas, {df.shape[1]} colunas")

import os
print(os.getcwd())  # Mostra o diretório atual
# Out:
# Dados carregados: 1599999 linhas, 6 colunas
# c:\Users\rafae\git\pipeline\bronze

# %% [markdown]
# Adicionar informações de quando os dados foram carregados

# %%
df['data_ingestao'] = dt.now()
df['fonte_arquivo'] = 'twitter_sentment.csv'

# %% [markdown]
# Salvar na camada Bronze (sem modificar os dados originais)

# %%
df.to_csv('twitter_sentment.csv', index=False)
print("Dados salvos na camada Bronze")

import os
print(os.getcwd())
# Out:
# Dados salvos na camada Bronze
# c:\Users\rafae\git\pipeline\bronze

# %%
df.head()
# Out:
#    0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY _TheSpecialOne_  \
# 0  0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY   scotthamilton
# 1  0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY        mattycus
# 2  0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY         ElleCTF
# 3  0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          Karoli
# 4  0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY        joy_wolf
#
#   @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D  \
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew
#
#                data_ingestao         fonte_arquivo
# 0 2025-10-31 23:42:18.204915  twitter_sentment.csv
# ...
